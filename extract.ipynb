# %%
# Imports

import pandas as pd

# %%
# Read excel file

df = pd.read_excel('data/MOSAIC - Desbloqueado.xlsx', sheet_name='Background')
df = df.drop(0)

# df = df.iloc[:, [0, -3, -2, -1]]
# df.to_csv('Background.csv', index=False)
df
# Out:
#       Wavelength  Scattered Moonlight   Scattered Starlight   Zodiacal Light  \
# 1            390           208.842085              6.313042        13.287076
# 2         390.02           268.728816              8.134738        17.097465
# 3         390.04           310.398712              9.410466        19.749009
# 4         390.06           333.188265             10.114381        21.199464
# 5         390.08           343.079252             10.419344        21.829358
# ...          ...                  ...                   ...              ...
# 29594   1884.485             0.620309              0.018831         1.014648
# 29595     1884.6             1.590072              0.047279         2.348454
# 29596   1884.715             2.537832              0.074439         3.515600
# 29597    1884.83             3.100071              0.089765         4.059015
# 29598   1884.945             2.889646              0.082609         3.580848
#
# ...
